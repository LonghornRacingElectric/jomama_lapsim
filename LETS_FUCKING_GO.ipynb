# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("endurance_michigan_2019-easy_driver.csv")
plt.scatter(x=df["x"],y=df["y"], c=df["vel"]/70, cmap="summer")
plt.title("LETS FUCKING GO")
print("TIME IN SECONDS 1 g-g diagram",df.loc[df.shape[0]-1, "time"])
# Out:
# TIME IN SECONDS 1 g-g diagram 130.65644914418627
